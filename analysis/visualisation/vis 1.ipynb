# %%
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(r"F:\Digipodium\titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data=df, x="class" , y="fare")
plt.title("Fare Distribution by class")
plt.xlabel("Class")
plt.ylabel("Fare")
plt.show()
# Out:
# c:\Users\HP\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HP\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HP\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.barplot(data=df, x="class" , y="survived")
plt.title("Survived by class")
plt.xlabel("Class")
plt.ylabel("survived")
plt.show()
# Out:
# c:\Users\HP\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HP\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\HP\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df = pd.read_csv(r"F:\Digipodium\titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Bar Chart showing the count of passengers in easy class
fig = px.bar(df, x='class', title = 'Bar Chart', labels ={'class':'Class','count':'Count'},
              color ='class', color_discrete_sequence=px.colors.sequential.Sunsetdark)
fig.show()

# %%
fig = px.bar(df, x='class', title = 'Bar Chart', labels ={'class':'Class','count':'Count'},
              color ='class', color_discrete_sequence=px.colors.sequential.Viridis)
fig.show()

# %%
class_count = df['class'].value_counts().reset_index()
class_count.columns = ['class' , 'count']
fig = px.bar(class_count, x='class', y='count', labels = {'class':'Class', 'count':'Count',},
             title='passenger class distribution' , color='class' , color_discrete_sequence = px.colors.sequential.Viridis)
fig.show()

# %%
import plotly.figure_factory as ff

# %%
scater_matrix = ff.create_scatterplotmatrix(df[['age','fare','pclass']] , diag = 'box',index = 'pclass',
                                             colormap = 'Portland' , title = 'Scatterplot Matrix' , height = 700 , width = 700)
scater_matrix.show()

# %%
fig = px.sunburst(df, path=['age','fare','pclass'],values = 'pclass' ,title='Sunburst Chart')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\Digipodium\analysis\visualisation\vis 1.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/Digipodium/analysis/visualisation/vis%201.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> fig = px.sunburst(df, path=['age','fare','pclass'],values = 'pclass' ,title='Sunburst Chart')
#       <a href='vscode-notebook-cell:/f%3A/Digipodium/analysis/visualisation/vis%201.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# File c:\Users\HP\miniconda3\Lib\site-packages\plotly\express\_chart_types.py:1541, in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539 if path is not None and branchvalues is None:
# ...
